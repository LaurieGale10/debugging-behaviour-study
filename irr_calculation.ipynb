# %% [markdown]
# # mv alpha calculation
#
# This notebook contains the implementation for calculating the multi-value alpha of a sample of our coded dataset.
#
# We ran two IRR rounds on the final categorisation: one between the first and second author and the other between the first author and a research colleague. mv-alpha is calculated per category in each case.
#
# Here's a summary of the notebook sections:
# 1. Install libraries and load data
# 2. IRR attempt 1
# 3. IRR attempt 2

# %% [markdown]
# ## Install libraries

# %%
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(stringr))
suppressPackageStartupMessages(library(mvalpha))

source("irr/irr_calculation_utils.r")
first_move_codes <- get_first_move_codes()
positive_debugging_behaviour_indicator_codes <- get_positive_debugging_indicator_codes()
added_error_codes <- get_added_error_codes()
resolved_error_codes <- get_resolved_error_codes()
inconsequential_change_codes <- get_inconsequential_change_codes()
miscellaneous_behaviour_codes <- get_miscellaneous_behaviour_codes()
# Out:
# Warning message:
# "package 'mvalpha' was built under R version 4.5.2"

# %% [markdown]
# The `extract_category_dataframe` function below is used for filtering each unit's code to a relevant category (used for calculating mv-alpha per category).

# %% [markdown]
# ## IRR attempt 1
# We now complete the first IRR round between the first and second author of the paper.
#
# We calculate an mv-alpha value *per category* rather than for the whole categorisation for three main reasons:
# - It is recommended by other guidelines (Krippendorff, 2004; Feng, 2013)
# - It gives a more granular picture of the reliability of the categorisation, which is more appropriate than a whole mv-alpha value.
# - Some of the units have too many codes to calculate an mv-alpha value for the entire dataset (the `mvalpha` function won't complete).
#
# Note that the names of some of the sub-categories here are different to the categorisation paper to ensure uniqueness (otherwise there'd be multiple codes with the same name, which could artificially inflate agreement).

# %%
df <- read.table("irr/attempt_1/irr_attempt_1.txt", sep = "\t", header = FALSE, stringsAsFactors = FALSE)
df[] <- lapply(df, function(col) lapply(col, function(x) strsplit(x, ",")[[1]]))

# %% [markdown]
# ### 1. First move
# Codes for this category are mutually exclusive, so we use Krippendorff's alpha rather than mv-alpha here

# %%
source("irr_calculation_utils.r")
first_move_dataframe <- extract_category_dataframe(df, first_move_codes)

first_move_csv <- create_category_csv_with_agreement(first_move_dataframe)
write.csv(first_move_csv, "attempt_1/irr_attempt_1_first_move_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(first_move_csv)$percentage_agreement))

source("mvalpha_cpp.r")
first_move_alpha <- mvalpha_cpp(first_move_dataframe, type = "nominal")
print(first_move_alpha)
# Out:
# [1] "Total agreement: 92.5"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 2
# n Values: 3
# Max Cardinality: 1
# Possible C-K pairs: 7
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 2, rate = 929 pairs/sec
# |C| = 1, |K| = 1, pairs = 4, rate = 2386 pairs/sec
#
# Total combinations: 7, Overall rate: 5159 pairs/sec
# mvalpha (nominal):
# 0.9004

# %% [markdown]
# ### 2. Positive debugging indicators

# %%
source("irr_calculation_utils.r")
positive_debugging_indicator_dataframe <- extract_category_dataframe(
    df,
    positive_debugging_indicator_codes
)

positive_debugging_indicator_csv <- create_category_csv_with_agreement(positive_debugging_indicator_dataframe)
write.csv(positive_debugging_indicator_csv, "attempt_1/irr_attempt_1_positive_debugging_indicator_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(positive_debugging_indicator_csv)$percentage_agreement))

source("mvalpha_cpp.r")
positive_debugging_indicator_alpha <- mvalpha_cpp(positive_debugging_indicator_dataframe, type = "nominal")
print(positive_debugging_indicator_alpha)
# Out:
# [1] "Total agreement: 72.7272727272727"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 1
# n Values: 2
# Max Cardinality: 1
# Possible C-K pairs: 3
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 1, rate = 7496 pairs/sec
# |C| = 1, |K| = 1, pairs = 1, rate = 6445 pairs/sec
#
# Total combinations: 3, Overall rate: 6904 pairs/sec
# mvalpha (nominal):
# 0.4135

# %% [markdown]
# ### 3. Added errors

# %% [markdown]
# On the first attempt, the `mvalpha` function did not complete.

# %%
source("irr_calculation_utils.r")
added_error_dataframe <- extract_category_dataframe(df, added_error_codes)

added_error_csv <- create_category_csv_with_agreement(added_error_dataframe)
write.csv(added_error_csv, "attempt_1/irr_attempt_1_added_error_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(added_error_csv)$percentage_agreement))

source("mvalpha_cpp.r")
added_error_alpha <- mvalpha_cpp(added_error_dataframe, type = "nominal")
print(added_error_alpha)
# Out:
# [1] "Total agreement: 34.6153846153846"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 21
# n Values: 46
# Max Cardinality: 7
# Possible C-K pairs: 28,147,884,582
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 21, rate = 6854 pairs/sec
# |C| = 0, |K| = 2, pairs = 210, rate = 93656 pairs/sec
# |C| = 0, |K| = 3, pairs = 1330, rate = 725680 pairs/sec
# |C| = 0, |K| = 4, pairs = 5985, rate = 2912548 pairs/sec
# |C| = 0, |K| = 5, pairs = 20349, rate = 8374389 pairs/sec
# |C| = 0, |K| = 6, pairs = 54264, rate = 15849099 pairs/sec
# |C| = 0, |K| = 7, pairs = 116280, rate = 20180286 pairs/sec
# |C| = 1, |K| = 1, pairs = 441, rate = 20718961 pairs/sec
# |C| = 1, |K| = 2, pairs = 4410, rate = 20486510 pairs/sec
# |C| = 1, |K| = 3, pairs = 27930, rate = 20062271 pairs/sec
# |C| = 1, |K| = 4, pairs = 125685, rate = 20879062 pairs/sec
# |C| = 1, |K| = 5, pairs = 427329, rate = 28814112 pairs/sec
# |C| = 1, |K| = 6, pairs = 1139544, rate = 44617874 pairs/sec
# |C| = 1, |K| = 7, pairs = 2441880, rate = 62667281 pairs/sec
# |C| = 2, |K| = 2, pairs = 44100, rate = 62757626 pairs/sec
# |C| = 2, |K| = 3, pairs = 279300, rate = 63044110 pairs/sec
# |C| = 2, |K| = 4, pairs = 1256850, rate = 65019981 pairs/sec
# |C| = 2, |K| = 5, pairs = 4273290, rate = 71923418 pairs/sec
# |C| = 2, |K| = 6, pairs = 11395440, rate = 78710699 pairs/sec
# |C| = 2, |K| = 7, pairs = 24418800, rate = 76812039 pairs/sec
# |C| = 3, |K| = 3, pairs = 1768900, rate = 74196514 pairs/sec
# |C| = 3, |K| = 4, pairs = 7960050, rate = 75413557 pairs/sec
# |C| = 3, |K| = 5, pairs = 27064170, rate = 78948630 pairs/sec
# |C| = 3, |K| = 6, pairs = 72171120, rate = 77105306 pairs/sec
# |C| = 3, |K| = 7, pairs = 154652400, rate = 77039866 pairs/sec
# |C| = 4, |K| = 4, pairs = 35820225, rate = 54708327 pairs/sec
# |C| = 4, |K| = 5, pairs = 121788765, rate = 54352321 pairs/sec
# |C| = 4, |K| = 6, pairs = 324770040, rate = 41977766 pairs/sec
# |C| = 4, |K| = 7, pairs = 695935800, rate = 36730029 pairs/sec
# |C| = 5, |K| = 5, pairs = 414081801, rate = 38005407 pairs/sec
# |C| = 5, |K| = 6, pairs = 1104218136, rate = 36645873 pairs/sec
# |C| = 5, |K| = 7, pairs = 2366181720, rate = 31976441 pairs/sec
# |C| = 6, |K| = 6, pairs = 2944581696, rate = 30548720 pairs/sec
# |C| = 6, |K| = 7, pairs = 6309817920, rate = 29192026 pairs/sec
# |C| = 7, |K| = 7, pairs = 13521038400, rate = 27560057 pairs/sec
#
# Total combinations: 28147884582, Overall rate: 26491178 pairs/sec
# mvalpha (nominal):
# 0.4217

# %% [markdown]
# ### 4. Resolved errors

# %%
source("irr_calculation_utils.r")
resolved_error_dataframe <- extract_category_dataframe(df, resolved_error_codes)

resolved_error_csv <- create_category_csv_with_agreement(resolved_error_dataframe)
write.csv(resolved_error_csv, "attempt_1/irr_attempt_1_resolved_error_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(resolved_error_csv)$percentage_agreement))

source("mvalpha_cpp.r")
resolved_error_alpha <- mvalpha_cpp(resolved_error_dataframe, type = "nominal")
print(resolved_error_alpha)
# Out:
# [1] "Total agreement: 45.2173913043478"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 13
# n Values: 44
# Max Cardinality: 5
# Possible C-K pairs: 3,960,022
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 13, rate = 5665 pairs/sec
# |C| = 0, |K| = 2, pairs = 78, rate = 44843 pairs/sec
# |C| = 0, |K| = 3, pairs = 286, rate = 190043 pairs/sec
# |C| = 0, |K| = 4, pairs = 715, rate = 637329 pairs/sec
# |C| = 0, |K| = 5, pairs = 1287, rate = 1342257 pairs/sec
# |C| = 1, |K| = 1, pairs = 169, rate = 2261067 pairs/sec
# |C| = 1, |K| = 2, pairs = 1014, rate = 2179191 pairs/sec
# |C| = 1, |K| = 3, pairs = 3718, rate = 2604912 pairs/sec
# |C| = 1, |K| = 4, pairs = 9295, rate = 4283697 pairs/sec
# |C| = 1, |K| = 5, pairs = 16731, rate = 8284686 pairs/sec
# |C| = 2, |K| = 2, pairs = 6084, rate = 13664410 pairs/sec
# |C| = 2, |K| = 3, pairs = 22308, rate = 14189330 pairs/sec
# |C| = 2, |K| = 4, pairs = 55770, rate = 17130997 pairs/sec
# |C| = 2, |K| = 5, pairs = 100386, rate = 26404648 pairs/sec
# |C| = 3, |K| = 3, pairs = 81796, rate = 35603621 pairs/sec
# |C| = 3, |K| = 4, pairs = 204490, rate = 39214149 pairs/sec
# |C| = 3, |K| = 5, pairs = 368082, rate = 53179430 pairs/sec
# |C| = 4, |K| = 4, pairs = 511225, rate = 58836191 pairs/sec
# |C| = 4, |K| = 5, pairs = 920205, rate = 65555071 pairs/sec
# |C| = 5, |K| = 5, pairs = 1656369, rate = 65994012 pairs/sec
#
# Total combinations: 3960022, Overall rate: 62503405 pairs/sec
# mvalpha (nominal):
# 0.5009

# %% [markdown]
# ### 5. Inconsequential changes

# %%
source("irr_calculation_utils.r")
inconsequential_change_dataframe <- extract_category_dataframe(
    df,
    inconsequential_change_codes
)

inconsequential_changes_csv <- create_category_csv_with_agreement(inconsequential_change_dataframe)
write.csv(inconsequential_changes_csv, "attempt_1/irr_attempt_1_inconsequential_changes_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(inconsequential_changes_csv)$percentage_agreement))

source("mvalpha_cpp.r")
inconsequential_changes_alpha <- mvalpha_cpp(inconsequential_change_dataframe, type = "nominal")
print(inconsequential_changes_alpha)
# Out:
# [1] "Total agreement: 47.6190476190476"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 8
# n Values: 24
# Max Cardinality: 5
# Possible C-K pairs: 29,991
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 8, rate = 4073 pairs/sec
# |C| = 0, |K| = 2, pairs = 28, rate = 24200 pairs/sec
# |C| = 0, |K| = 3, pairs = 56, rate = 79518 pairs/sec
# |C| = 0, |K| = 4, pairs = 70, rate = 166160 pairs/sec
# |C| = 0, |K| = 5, pairs = 56, rate = 259968 pairs/sec
# |C| = 1, |K| = 1, pairs = 64, rate = 317069 pairs/sec
# |C| = 1, |K| = 2, pairs = 224, rate = 366058 pairs/sec
# |C| = 1, |K| = 3, pairs = 448, rate = 589466 pairs/sec
# |C| = 1, |K| = 4, pairs = 560, rate = 1004417 pairs/sec
# |C| = 1, |K| = 5, pairs = 448, rate = 1452958 pairs/sec
# |C| = 2, |K| = 2, pairs = 784, rate = 1743029 pairs/sec
# |C| = 2, |K| = 3, pairs = 1568, rate = 2284597 pairs/sec
# |C| = 2, |K| = 4, pairs = 1960, rate = 3300696 pairs/sec
# |C| = 2, |K| = 5, pairs = 1568, rate = 4391797 pairs/sec
# |C| = 3, |K| = 3, pairs = 3136, rate = 5076046 pairs/sec
# |C| = 3, |K| = 4, pairs = 3920, rate = 6346609 pairs/sec
# |C| = 3, |K| = 5, pairs = 3136, rate = 7920786 pairs/sec
# |C| = 4, |K| = 4, pairs = 4900, rate = 8818208 pairs/sec
# |C| = 4, |K| = 5, pairs = 3920, rate = 10101744 pairs/sec
# |C| = 5, |K| = 5, pairs = 3136, rate = 11050076 pairs/sec
#
# Total combinations: 29991, Overall rate: 11618114 pairs/sec
# mvalpha (nominal):
# 0.5265

# %% [markdown]
# ### 6. Miscellaneous behaviours

# %%
source("irr_calculation_utils.r")
miscellaneous_behaviour_dataframe <- extract_category_dataframe(
    df,
    miscellaneous_behaviour_codes
)

miscellaneous_behaviour_csv <- create_category_csv_with_agreement(miscellaneous_behaviour_dataframe)
write.csv(miscellaneous_behaviour_csv, "attempt_1/irr_attempt_1_miscellaneous_behaviour_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(miscellaneous_behaviour_csv)$percentage_agreement))

source("mvalpha_cpp.r")
miscellaneous_behaviour_alpha <- mvalpha_cpp(miscellaneous_behaviour_dataframe, type = "nominal")
print(miscellaneous_behaviour_alpha)
# Out:
# [1] "Total agreement: 69.2307692307692"
# Using 11 OpenMP threads
# n Units: 39
# n Observers: 2
# n Labels: 1
# n Values: 2
# Max Cardinality: 1
# Possible C-K pairs: 3
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 1, rate = 7886 pairs/sec
# |C| = 1, |K| = 1, pairs = 1, rate = 9394 pairs/sec
#
# Total combinations: 3, Overall rate: 9970 pairs/sec
# mvalpha (nominal):
# 0.5829

# %% [markdown]
# ## IRR attempt 2 - pilot
# This IRR attempt was conducted with a different rater (a research colleague) on four exercise attempts. We start off by loading the data (using a different approach to others).
# For each column:
# - Create a dataframe where each row's index is a column in the dataset
# - Then for each row, populate with columns that say "yes"

# %%
# Load the two pilot rater CSVs (with final row related to "any other comments" removed)
rater1_df <- read.csv("attempt_2_pilot/irr_attempt_2_rater_1_pilot.csv", stringsAsFactors = FALSE, check.names = FALSE)
rater2_df <- read.csv("attempt_2_pilot/irr_attempt_2_rater_2_pilot.csv", stringsAsFactors = FALSE, check.names = FALSE)

rater1_df <- rater1_df[-nrow(rater1_df), ]
rater2_df <- rater2_df[-nrow(rater2_df), ]

rater_codes <- data.frame(
  rater1 = I(vector("list", ncol(rater1_df) - 1)),
  rater2 = I(vector("list", ncol(rater1_df) - 1))
)

for (col_index in 2:5) {
    #Get codes where raters have categorised the behaviour as "yes"
    rater1_yes <- tolower(rater1_df[[col_index]]) == "yes"
    rater2_yes <- tolower(rater2_df[[col_index]]) == "yes"

    rater1_codes <- trimws(rater1_df[[1]][rater1_yes])
    rater2_codes <- trimws(rater2_df[[1]][rater2_yes])

    #Aggregate these codes in the rater_codes DF
    rater_codes[[1]][[col_index - 1]] <- rater1_codes
    rater_codes[[2]][[col_index - 1]] <- rater2_codes
}

write.csv(rater_codes, "attempt_2_pilot/irr_attempt_2_pilot_aggregate_codes.csv", row.names = FALSE)

# %% [markdown]
# ### 1. First move

# %%
source("irr_calculation_utils.r")
first_move_dataframe <- extract_category_dataframe(rater_codes, first_move_codes)
print(first_move_dataframe)

source("mvalpha_cpp.r")
first_move_alpha <- mvalpha_cpp(first_move_dataframe, type = "nominal")
print(first_move_alpha)
# Out:
#                             rater1                           rater2
# 1 Made changes before running code Made changes before running code
# 2   Ran code before making changes   Ran code before making changes
# 3 Made changes before running code Made changes before running code
# 4 Made changes before running code Made changes before running code
# Using 11 OpenMP threads
# n Units: 4
# n Observers: 2
# n Labels: 2
# n Values: 2
# Max Cardinality: 1
# Possible C-K pairs: 4
# |C| = 1, |K| = 1, pairs = 4
#
# Total combinations: 4, Overall rate: 3960 pairs/sec
# mvalpha (nominal):
# 1

# %% [markdown]
# ### 2. Positive debugging behaviours

# %%
source("irr_calculation_utils.r")
positive_debugging_indicator_dataframe <- extract_category_dataframe(
    rater_codes,
    positive_debugging_indicator_codes
)
print(positive_debugging_indicator_dataframe)

source("mvalpha_cpp.r")
positive_debugging_indicator_alpha <- mvalpha(positive_debugging_indicator_dataframe, type = "nominal")
print(positive_debugging_indicator_alpha)
# Out:
# Error: object 'rater_codes' not found
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'rater_codes' not found", base::quote(eval(expr, envir)))

# %% [markdown]
# ### 3. Added errors

# %%
source("irr_calculation_utils.r")
added_error_dataframe <- extract_category_dataframe(rater_codes, added_error_codes)
print(added_error_dataframe)

source("mvalpha_cpp.r")
added_error_alpha <- mvalpha_cpp(added_error_dataframe, type = "nominal",verbose = FALSE)
print(added_error_alpha)
# Out:
#                                                                                                                                                                                                                                                    rater1
# 1                                                                                                  Incorrect syntactical changes to output statements, Incorrect syntactical changes to other symbols, Incorrect semantic changes to variable assignments
# 2 Incorrect syntactical changes to variable assignments, Incorrect syntactical changes to other symbols, Incorrect syntactical changes involving fusion or distribution of multiple lines of code, Incorrect syntactical changes to whitespace of program
# 3                                                                                                  Incorrect syntactical changes to output statements, Incorrect syntactical changes to other symbols, Incorrect semantic changes to variable assignments
# 4                                                                                                                                                                                                 Logically incorrect changes involving output statements
#                                                                                                      rater2
# 1     Incorrect syntactical changes to variable assignments, Incorrect syntactical changes to other symbols
# 2                     Reverted corrective change(s), Incorrect syntactical changes to whitespace of program
# 3 Incorrect syntactical changes to output statements, Incorrect syntactical changes to variable assignments
# 4                                                                                                      NULL
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 8, rate = 5390 pairs/sec
# |C| = 0, |K| = 2, pairs = 28, rate = 28418 pairs/sec
# |C| = 0, |K| = 3, pairs = 56, rate = 87202 pairs/sec
# |C| = 0, |K| = 4, pairs = 70, rate = 118200 pairs/sec
# |C| = 1, |K| = 1, pairs = 64, rate = 146122 pairs/sec
# |C| = 1, |K| = 2, pairs = 224, rate = 182917 pairs/sec
# |C| = 1, |K| = 3, pairs = 448, rate = 338359 pairs/sec
# |C| = 1, |K| = 4, pairs = 560, rate = 618081 pairs/sec
# |C| = 2, |K| = 2, pairs = 784, rate = 900506 pairs/sec
# |C| = 2, |K| = 3, pairs = 1568, rate = 1268163 pairs/sec
# |C| = 2, |K| = 4, pairs = 1960, rate = 1871164 pairs/sec
# |C| = 3, |K| = 3, pairs = 3136, rate = 2613440 pairs/sec
# |C| = 3, |K| = 4, pairs = 3920, rate = 3701841 pairs/sec
# |C| = 4, |K| = 4, pairs = 4900, rate = 4724667 pairs/sec
#
# Total combinations: 17727, Overall rate: 5637641 pairs/sec
# NULL

# %% [markdown]
# ### 4. Resolved errors

# %%
source("irr_calculation_utils.r")
resolved_error_dataframe <- extract_category_dataframe(rater_codes, resolved_error_codes)
print(resolved_error_dataframe)

source("mvalpha_cpp.r")
resolved_error_alpha <- mvalpha_cpp(resolved_error_dataframe, type = "nominal")
print(resolved_error_alpha)
# Out:
#                                                                                                                                                                                                                       rater1
# 1                                                                                                                          Resolved syntax error by changing syntax of erroneous component, Correctly resolved runtime error
# 2                                                                                                                                                                                            Correctly resolved syntax error
# 3 Correctly resolved syntax error, Resolved syntax error by changing syntax of erroneous component, Correctly resolved logical error while code not running, Correctly resolved logical error after repeated successful runs
# 4                           Correctly resolved runtime error, Correctly resolved type error, Correctly resolved logical error after a single successful run, Correctly resolved logical error after repeated successful runs
#                                                                                                                                                           rater2
# 1                             Correctly resolved syntax error, Resolved syntax error by changing syntax of erroneous component, Correctly resolved runtime error
# 2                                                                                                Resolved syntax error by changing syntax of erroneous component
# 3                                                                                                        Correctly resolved logical error while code not running
# 4 Resolved syntax error by changing syntax of erroneous component, Correctly resolved type error, Correctly resolved logical error after a single successful run
# Using 11 OpenMP threads
# n Units: 4
# n Observers: 2
# n Labels: 7
# n Values: 8
# Max Cardinality: 4
# Possible C-K pairs: 6,272
# |C| = 1, |K| = 1, pairs = 49
# |C| = 1, |K| = 2, pairs = 147, rate = 233555 pairs/sec
# |C| = 1, |K| = 3, pairs = 245, rate = 496579 pairs/sec
# |C| = 1, |K| = 4, pairs = 245, rate = 766157 pairs/sec
# |C| = 2, |K| = 2, pairs = 441, rate = 1003070 pairs/sec
# |C| = 2, |K| = 3, pairs = 735, rate = 1396011 pairs/sec
# |C| = 2, |K| = 4, pairs = 735, rate = 1924348 pairs/sec
# |C| = 3, |K| = 3, pairs = 1225, rate = 2386948 pairs/sec
# |C| = 3, |K| = 4, pairs = 1225, rate = 3074818 pairs/sec
# |C| = 4, |K| = 4, pairs = 1225, rate = 2997742 pairs/sec
#
# Total combinations: 6272, Overall rate: 3137411 pairs/sec
# mvalpha (nominal):
# 0.2501

# %% [markdown]
# ### 5. Inconsequential changes

# %%
source("irr_calculation_utils.r")
inconsequential_change_dataframe <- extract_category_dataframe(
    rater_codes,
    inconsequential_change_codes
)
print(inconsequential_change_dataframe)

source("mvalpha_cpp.r")
inconsequential_changes_alpha <- mvalpha_cpp(inconsequential_change_dataframe, type = "nominal")
print(inconsequential_changes_alpha)
# Out:
#                                                                                                                                              rater1
# 1                                                                                                                                              NULL
# 2 Inconsequential changes involving symbols, Inconsequential changes to variable references, Inconsequential changes to (existing) other statements
# 4                                                                                                                      Addition of unnecessary code
#                                           rater2
# 1 Inconsequential changes to variable references
# 2      Inconsequential changes involving symbols
# 4 Inconsequential changes to variable references
# Using 11 OpenMP threads
# n Units: 3
# n Observers: 2
# n Labels: 4
# n Values: 5
# Max Cardinality: 3
# Possible C-K pairs: 57
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 4, rate = 6896 pairs/sec
# |C| = 0, |K| = 3, pairs = 4, rate = 19809 pairs/sec
# |C| = 1, |K| = 1, pairs = 16, rate = 23622 pairs/sec
# |C| = 1, |K| = 3, pairs = 16, rate = 50968 pairs/sec
# |C| = 3, |K| = 3, pairs = 16, rate = 70410 pairs/sec
#
# Total combinations: 57, Overall rate: 81790 pairs/sec
# mvalpha (nominal):
# -0.0454

# %% [markdown]
# ### 6. Miscallenous behaviours

# %%
source("irr_calculation_utils.r")
miscellaneous_behaviour_dataframe <- extract_category_dataframe(
    rater_codes,
    miscellaneous_behaviour_codes
)
print(miscellaneous_behaviour_dataframe)

source("mvalpha_cpp.r")
miscellaneous_behaviour_alpha <- mvalpha_cpp(miscellaneous_behaviour_dataframe, type = "nominal")
print(miscellaneous_behaviour_alpha)
# Out:
#                                                                                                         rater1
# 1                                                  Repeatedly ran erroneous program, Reverted previous changes
# 2 Repeatedly ran erroneous program, Repeatedly ran program at beginning of exercise, Reverted previous changes
# 3                                                  Repeatedly ran erroneous program, Reverted previous changes
# 4                                                                                    Reverted previous changes
#                                                                              rater2
# 1                                                  Repeatedly ran erroneous program
# 2 Repeatedly ran erroneous program, Repeatedly ran program at beginning of exercise
# 3                                                  Repeatedly ran erroneous program
# 4                                                                              NULL
# Using 11 OpenMP threads
# n Units: 4
# n Observers: 2
# n Labels: 3
# n Values: 6
# Max Cardinality: 3
# Possible C-K pairs: 42
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 3, rate = 6734 pairs/sec
# |C| = 0, |K| = 2, pairs = 3, rate = 16070 pairs/sec
# |C| = 0, |K| = 3, pairs = 1, rate = 17980 pairs/sec
# |C| = 1, |K| = 1, pairs = 9, rate = 15766 pairs/sec
# |C| = 1, |K| = 2, pairs = 9, rate = 27846 pairs/sec
# |C| = 1, |K| = 3, pairs = 3, rate = 37599 pairs/sec
# |C| = 2, |K| = 2, pairs = 9, rate = 36528 pairs/sec
# |C| = 2, |K| = 3, pairs = 3, rate = 43010 pairs/sec
# |C| = 3, |K| = 3, pairs = 1, rate = 40885 pairs/sec
#
# Total combinations: 42, Overall rate: 38040 pairs/sec
# mvalpha (nominal):
# 0.195

# %% [markdown]
# ## IRR attempt 2 - full
# The final round of IRR conducted with the same colleague as the previous pilot round, this time on 24 exercise attempts (7.5% of the sample).

# %%
# Load the two pilot rater CSVs (with final row related to "any other comments" removed)
rater1_df <- read.csv("attempt_2/irr_attempt_2_rater_1.csv", stringsAsFactors = FALSE, check.names = FALSE)
rater2_df <- read.csv("attempt_2/irr_attempt_2_rater_2.csv", stringsAsFactors = FALSE, check.names = FALSE)

rater1_df <- rater1_df[-nrow(rater1_df), ]
rater2_df <- rater2_df[-nrow(rater2_df), ]

rater_codes <- data.frame(
  rater1 = I(vector("list", ncol(rater1_df) - 1)),
  rater2 = I(vector("list", ncol(rater1_df) - 1))
)

for (col_index in 2:length(rater1_df)) {
    #Get codes where raters have categorised the behaviour as "yes"
    rater1_yes <- tolower(rater1_df[[col_index]]) == "yes"
    rater2_yes <- tolower(rater2_df[[col_index]]) == "yes"

    rater1_codes <- trimws(rater1_df[[1]][rater1_yes])
    rater2_codes <- trimws(rater2_df[[1]][rater2_yes])

    #Aggregate these codes in the rater_codes DF
    rater_codes[[1]][[col_index - 1]] <- rater1_codes
    rater_codes[[2]][[col_index - 1]] <- rater2_codes
}

# %% [markdown]
# ### 1. First move

# %%
source("irr_calculation_utils.r")
first_move_dataframe <- extract_category_dataframe(rater_codes, first_move_codes)

source("mvalpha_cpp.r")
first_move_csv <- create_category_csv_with_agreement(first_move_dataframe)

write.csv(first_move_csv, "attempt_2/irr_attempt_2_first_move_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(first_move_csv)$percentage_agreement))
first_move_alpha <- mvalpha(first_move_dataframe, type = "nominal")
print(first_move_alpha)
# Out:
# [1] "Total agreement: 84.6153846153846"
# n Units: 24
# n Observers: 2
# n Labels: 2
# n Values: 2
# Max Cardinality: 1
# Possible C-K pairs: 4
# |C| = 1, |K| = 1, C-K pairs to evaluate = 4
# mvalpha (nominal):
# 0.8164

# %% [markdown]
# ### 2. Positive debugging behaviours

# %%
source("irr_calculation_utils.r")
positive_debugging_indicator_dataframe <- extract_category_dataframe(
    rater_codes,
    positive_debugging_indicator_codes
)

positive_debugging_indicator_csv <- create_category_csv_with_agreement(positive_debugging_indicator_dataframe)
write.csv(positive_debugging_indicator_csv, "attempt_2/irr_attempt_2_positive_debugging_indicator_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(positive_debugging_indicator_csv)$percentage_agreement))

source("mvalpha_cpp.r")
positive_debugging_indicator_alpha <- mvalpha(positive_debugging_indicator_dataframe, type = "nominal")
print(positive_debugging_indicator_alpha)
# Out:
# [1] "Total agreement: 66.6666666666667"
# n Units: 24
# n Observers: 2
# n Labels: 2
# n Values: 3
# Max Cardinality: 2
# Possible C-K pairs: 11
# |C| = 0, |K| = 0, C-K pairs to evaluate = 1
# |C| = 0, |K| = 1, C-K pairs to evaluate = 2
# |C| = 0, |K| = 2, C-K pairs to evaluate = 1
# |C| = 1, |K| = 1, C-K pairs to evaluate = 4
# |C| = 1, |K| = 2, C-K pairs to evaluate = 2
# |C| = 2, |K| = 2, C-K pairs to evaluate = 1
# mvalpha (nominal):
# 0.4095

# %% [markdown]
# ### 3. Added errors

# %%
source("irr_calculation_utils.r")
added_error_dataframe <- extract_category_dataframe(rater_codes, added_error_codes)

added_error_csv <- create_category_csv_with_agreement(added_error_dataframe)
write.csv(added_error_csv, "attempt_2/irr_attempt_2_added_error_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(added_error_csv)$percentage_agreement))

source("mvalpha_cpp.r")
added_error_alpha <- mvalpha_cpp(added_error_dataframe, type = "nominal",verbose = FALSE)
print(added_error_alpha)
# Out:
# [1] "Total agreement: 40.7894736842105"
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 22, rate = 3229 pairs/sec
# |C| = 0, |K| = 2, pairs = 231, rate = 47315 pairs/sec
# |C| = 0, |K| = 3, pairs = 1540, rate = 447813 pairs/sec
# |C| = 0, |K| = 4, pairs = 7315, rate = 2122825 pairs/sec
# |C| = 0, |K| = 5, pairs = 26334, rate = 5798217 pairs/sec
# |C| = 0, |K| = 6, pairs = 74613, rate = 12226361 pairs/sec
# |C| = 0, |K| = 7, pairs = 170544, rate = 18156561 pairs/sec
# |C| = 0, |K| = 8, pairs = 319770, rate = 21743004 pairs/sec
# |C| = 1, |K| = 1, pairs = 484, rate = 22688262 pairs/sec
# |C| = 1, |K| = 2, pairs = 5082, rate = 22556950 pairs/sec
# |C| = 1, |K| = 3, pairs = 33880, rate = 22598337 pairs/sec
# |C| = 1, |K| = 4, pairs = 160930, rate = 23499320 pairs/sec
# |C| = 1, |K| = 5, pairs = 579348, rate = 27889965 pairs/sec
# |C| = 1, |K| = 6, pairs = 1641486, rate = 38663510 pairs/sec
# |C| = 1, |K| = 7, pairs = 3751968, rate = 53647926 pairs/sec
# |C| = 1, |K| = 8, pairs = 7034940, rate = 63927992 pairs/sec
# |C| = 2, |K| = 2, pairs = 53361, rate = 67273844 pairs/sec
# |C| = 2, |K| = 3, pairs = 355740, rate = 67344077 pairs/sec
# |C| = 2, |K| = 4, pairs = 1689765, rate = 68258526 pairs/sec
# |C| = 2, |K| = 5, pairs = 6083154, rate = 71293463 pairs/sec
# |C| = 2, |K| = 6, pairs = 17235603, rate = 76213849 pairs/sec
# |C| = 2, |K| = 7, pairs = 39395664, rate = 80933881 pairs/sec
# |C| = 2, |K| = 8, pairs = 73866870, rate = 79340112 pairs/sec
# |C| = 3, |K| = 3, pairs = 2371600, rate = 78280110 pairs/sec
# |C| = 3, |K| = 4, pairs = 11265100, rate = 78660506 pairs/sec
# |C| = 3, |K| = 5, pairs = 40554360, rate = 80369763 pairs/sec
# |C| = 3, |K| = 6, pairs = 114904020, rate = 81800315 pairs/sec
# |C| = 3, |K| = 7, pairs = 262637760, rate = 79869739 pairs/sec
# |C| = 3, |K| = 8, pairs = 492445800, rate = 75597307 pairs/sec
# |C| = 4, |K| = 4, pairs = 53509225, rate = 55232099 pairs/sec
# |C| = 4, |K| = 5, pairs = 192633210, rate = 55068483 pairs/sec
# |C| = 4, |K| = 6, pairs = 545794095, rate = 52767516 pairs/sec
# |C| = 4, |K| = 7, pairs = 1247529360, rate = 47771491 pairs/sec
# |C| = 4, |K| = 8, pairs = 2339117550, rate = 44511544 pairs/sec
# |C| = 5, |K| = 5, pairs = 693479556, rate = 44606689 pairs/sec
# |C| = 5, |K| = 6, pairs = 1964858742, rate = 43757742 pairs/sec
# |C| = 5, |K| = 7, pairs = 4491105696, rate = 42196878 pairs/sec
# |C| = 5, |K| = 8, pairs = 8420823180, rate = 39504347 pairs/sec
# |C| = 6, |K| = 6, pairs = 5567099769, rate = 36849180 pairs/sec
# |C| = 6, |K| = 7, pairs = 12724799472, rate = 35209235 pairs/sec
# |C| = 6, |K| = 8, pairs = 23858999010, rate = 33007172 pairs/sec
# |C| = 7, |K| = 7, pairs = 29085255936, rate = 30919396 pairs/sec
# |C| = 7, |K| = 8, pairs = 54534854880, rate = 30537304 pairs/sec
# |C| = 8, |K| = 8, pairs = 102252852900, rate = 29959645 pairs/sec
#
# Total combinations: 249049379866, Overall rate: 15309402 pairs/sec
# mvalpha (nominal):
# 0.4907

# %% [markdown]
# ### 4. Resolved errors

# %%
source("irr_calculation_utils.r")
resolved_error_dataframe <- extract_category_dataframe(rater_codes, resolved_error_codes)
resolved_error_dataframe <- resolved_error_dataframe[
  !apply(resolved_error_dataframe, 1, function(row) {
    any(vapply(row, is.null, logical(1)))
  }),
]

resolved_error_csv <- create_category_csv_with_agreement(resolved_error_dataframe)
write.csv(resolved_error_csv, "attempt_2/irr_attempt_2_resolved_error_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(resolved_error_csv)$percentage_agreement))

source("mvalpha_cpp.r")
resolved_error_alpha <- mvalpha(resolved_error_dataframe, type = "nominal")
print(resolved_error_alpha)
# Out:
# [1] "Total agreement: 26.6666666666667"
# n Units: 19
# n Observers: 2
# n Labels: 10
# n Values: 24
# Max Cardinality: 4
# Possible C-K pairs: 104,425
# |C| = 1, |K| = 1, C-K pairs to evaluate = 100
# |C| = 1, |K| = 2, C-K pairs to evaluate = 450
# |C| = 1, |K| = 3, C-K pairs to evaluate = 1,200
# |C| = 1, |K| = 4, C-K pairs to evaluate = 2,100
# |C| = 2, |K| = 2, C-K pairs to evaluate = 2,025
# |C| = 2, |K| = 3, C-K pairs to evaluate = 5,400
# |C| = 2, |K| = 4, C-K pairs to evaluate = 9,450
# |C| = 3, |K| = 3, C-K pairs to evaluate = 14,400
# |C| = 3, |K| = 4, C-K pairs to evaluate = 25,200
# |C| = 4, |K| = 4, C-K pairs to evaluate = 44,100
# mvalpha (nominal):
# 0.1939

# %% [markdown]
# ### 5. Inconsequential changes

# %%
source("irr_calculation_utils.r")
inconsequential_change_dataframe <- extract_category_dataframe(
    rater_codes,
    inconsequential_change_codes
)

inconsequential_change_csv <- create_category_csv_with_agreement(inconsequential_change_dataframe)
write.csv(inconsequential_change_csv, "attempt_2/irr_attempt_2_inconsequential_changes.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(inconsequential_change_csv)$percentage_agreement))

source("mvalpha_cpp.r")
inconsequential_changes_alpha <- mvalpha_cpp(inconsequential_change_dataframe, type = "nominal")
print(inconsequential_changes_alpha)
# Out:
# [1] "Total agreement: 24.4897959183673"
# Using 11 OpenMP threads
# n Units: 24
# n Observers: 2
# n Labels: 8
# n Values: 20
# Max Cardinality: 4
# Possible C-K pairs: 17,727
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 8, rate = 1117 pairs/sec
# |C| = 0, |K| = 2, pairs = 28, rate = 7630 pairs/sec
# |C| = 0, |K| = 3, pairs = 56, rate = 29344 pairs/sec
# |C| = 0, |K| = 4, pairs = 70, rate = 68156 pairs/sec
# |C| = 1, |K| = 1, pairs = 64, rate = 111354 pairs/sec
# |C| = 1, |K| = 2, pairs = 224, rate = 140783 pairs/sec
# |C| = 1, |K| = 3, pairs = 448, rate = 266737 pairs/sec
# |C| = 1, |K| = 4, pairs = 560, rate = 501478 pairs/sec
# |C| = 2, |K| = 2, pairs = 784, rate = 775733 pairs/sec
# |C| = 2, |K| = 3, pairs = 1568, rate = 1135236 pairs/sec
# |C| = 2, |K| = 4, pairs = 1960, rate = 1823532 pairs/sec
# |C| = 3, |K| = 3, pairs = 3136, rate = 2595807 pairs/sec
# |C| = 3, |K| = 4, pairs = 3920, rate = 3672686 pairs/sec
# |C| = 4, |K| = 4, pairs = 4900, rate = 4977106 pairs/sec
#
# Total combinations: 17727, Overall rate: 6466875 pairs/sec
# mvalpha (nominal):
# 0.1821

# %% [markdown]
# ### 6. Miscallenous behaviours

# %%
source("irr_calculation_utils.r")
miscellaneous_behaviour_dataframe <- extract_category_dataframe(
    rater_codes,
    miscellaneous_behaviour_codes
)

miscellaneous_behaviour_csv <- create_category_csv_with_agreement(miscellaneous_behaviour_dataframe)
write.csv(miscellaneous_behaviour_csv, "attempt_2/irr_attempt_2_miscallenous_behaviour_alpha.csv", row.names = FALSE)
print(paste("Total agreement:", calculate_total_agreement(miscellaneous_behaviour_csv)$percentage_agreement))

source("mvalpha_cpp.r")
miscellaneous_behaviour_alpha <- mvalpha_cpp(miscellaneous_behaviour_dataframe, type = "nominal",verbose = FALSE)
print(miscellaneous_behaviour_alpha)
# Out:
# [1] "Total agreement: 61.2903225806452"
# |C| = 0, |K| = 0, pairs = 1
# |C| = 0, |K| = 1, pairs = 3, rate = 10090 pairs/sec
# |C| = 0, |K| = 2, pairs = 3, rate = 21493 pairs/sec
# |C| = 1, |K| = 1, pairs = 9, rate = 29448 pairs/sec
# |C| = 1, |K| = 2, pairs = 9, rate = 50568 pairs/sec
# |C| = 2, |K| = 2, pairs = 9, rate = 61485 pairs/sec
#
# Total combinations: 34, Overall rate: 67661 pairs/sec
# mvalpha (nominal):
# 0.4307

# %% [markdown]
# ## References
# - Guangchao Charles Feng. 2014. Intercoder reliability indices: Disuse, misuse, and abuse. Quality and Quantity 48, 3 (5 2014), 1803–1815.
# https://doi.org/10.1007/s11135-013-9956-8
# - Klaus Krippendorff. 2004. Reliability in Content Analysis: Some Common Misconceptions and Recommendations. Human Communication Research 30, 3 (7 2004), 411–433. https://doi.org/10.1111/J.1468-2958.2004.TB00738.X
